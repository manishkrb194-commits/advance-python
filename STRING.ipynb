# %% [markdown]
# <a href="https://colab.research.google.com/github/manishkrb194-commits/advance-python/blob/main/STRING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 A = {"mango","ram",True,1}
 print(A)
# Out:
# {'mango', True, 'ram'}

# %%
#wap to remove all the vowels in a given string
s = input()
result = ""

for ch in s:
    if ch not in "aeiouAEIOU":
        result += ch

print(result)

# %%
#wap to check whether two string are anagrams of each other.

#wap to capitalize the first letter of each word in a string

#wap to check whether a given string is palindrome without usin built-in reverse function.
s = input()

left = 0
right = len(s) - 1
palindrome = True

while left < right:
    if s[left] != s[right]:
        palindrome = False
        break
    left += 1
    right -= 1

if palindrome:
    print("Palindrome")
else:
    print("Not Palindrome")

# %%
#wap to count the number of lower case and upper case character in a string
s = input()

lower = 0
upper = 0

for ch in s:
    if 'a' <= ch <= 'z':
        lower += 1
    elif 'A' <= ch <= 'Z':
        upper += 1

print("Lowercase:", lower)
print("Uppercase:", upper)

# %%
#wap to check whether a given string contain only digit
s = input()

only_digits = True
for ch in s:
    if ch < '0' or ch > '9':
        only_digits = False
        break

if only_digits:
    print("String contains only digits")
else:
    print("String does not contain only digits")

# %%
#wap to replace all spaces in a string with underscore(_).
s = input()

result = ""
for ch in s:
    if ch == ' ':
        result += '_'
    else:
        result += ch

print(result)

# %%
#wap to count the frequency of each character in a string
s = input()
freq = {}

for ch in s:
    if ch in freq:
        freq[ch] += 1
    else:
        freq[ch] = 1

for key in freq:
    print(key, ":", freq[key]

# %%
#wap to find first and last occurence of a character in a string
s = input()
ch = input()

first = -1
last = -1

for i in range(len(s)):
    if s[i] == ch:
        if first == -1:
            first = i
        last = i

print("First:", first)
print("Last:", last)

# %%
#wap to take a string input from the user and print it in reverse
s = input()
rev = ""
for i in range(len(s) - 1, -1, -1):
    rev += s[i]
print(rev)
